# %% [markdown]
# ![Screenshot (56).png](attachment:6d85d85b-1755-439a-a4ed-362b84351bbd.png)

# %%
inputs = [1, 2, 3]
weights = [0.2, 0.8, -0.5]
bias = 2
output = (inputs[0]*weights[0]+
          inputs[1]*weights[1]+
          inputs[2]*weights[2]+ bias)
output
# Out:
# 2.3

# %% [markdown]
# ![Screenshot (57).png](attachment:d39025d7-9082-4a94-9633-39541d0d4cc1.png)

# %%
inputss = [1, 2, 3, 2.5]
weights1 = [0.2, 0.8, -0.5, 1]
weights2 = [0.5, -0.91, 0.26, -0.5]
weights3 = [-0.26, -0.27, 0.17, 0.87]

bias1 = 2
bias2 = 3
bias3 = 0.5

outputs = [
    # Neuron 1:
    inputss[0]*weights1[0] +
    inputss[1]*weights1[1] +
    inputss[2]*weights1[2] +
    inputss[3]*weights1[3] + bias1,


    # Neuron 2: 
    inputss[0]*weights2[0] +
    inputss[1]*weights2[1] +
    inputss[2]*weights2[2] +
    inputss[3]*weights2[3] + bias2,

    # Neuron 3:
    inputss[0]*weights3[0] +
    inputss[1]*weights3[1] +
    inputss[2]*weights3[2] +
    inputss[3]*weights3[3] + bias3
]
outputs
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# ![Screenshot (57).png](attachment:f8c54548-4914-427c-87eb-82978d491816.png)

# %%
inputs = [1, 2, 3, 2.5]
weights = [[0.2, 0.8, -0.5, 1],
           [0.5, -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]
biases = [2, 3, 0.5]


# output of Layer
layer_output = []
# For each Neuron
for neuron_weights, neuron_bias in zip(weights, biases):
    # Output of each Neuron
    neuron_output = 0
    # For each input and weight to the neuron
    for n_inputs, weight in zip(inputs, neuron_weights):
        # Multiply this input by associated weight
        # and add to the neuron's output variable
        neuron_output += n_inputs*weight
    # Add bias
    neuron_output += neuron_bias
    #Put neuron's result to the layer's output list
    layer_output.append(neuron_output)

layer_output
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# # Using Numpy

# %% [markdown]
# ![Screenshot (58).png](attachment:0c00722a-5fb5-487d-8ec9-b18c46ab0871.png)

# %% [markdown]
# ![Screenshot (59).png](attachment:be9b3473-922d-4f7b-bf3b-ac7e6765922c.png)

# %%
import numpy as np
inputs  = [1.0, 2.0, 3.0, 2.5]
weights = [0.2, 0.8, -0.5, 1.0]
bias = 2.0

output = np.dot(weights, inputs) + bias

output
# Out:
# 4.8

# %% [markdown]
# # A Layer of Neurons with NumPy

# %% [markdown]
# ![Screenshot (60).png](attachment:3d0d8ece-266f-4bb8-a94a-2c062a62fab3.png)

# %%
inputs = [1.0, 2.0, 3.0, 2.5]

weights =  [[0.2, 0.8, -0.5, 1],
            [0.5, -0.91, 0.26, -0.5],
            [-0.26, -0.27, 0.17, 0.87]]

biasess = [2.0, 3.0, 0.5]

Layer_output = np.dot(weights, inputs) + biases
Layer_output
# Out:
# array([4.8  , 1.21 , 2.385])

# %% [markdown]
# # Batch Data (inputs)

# %%
inputs = [[1.0,2.0, 3.0, 2.5],
          [2.0, 5.0, -1.0, 2.0],
          [-1.5, 2.7, 3.3, -0.8]]

weights = [[0.2, 0.8, -0.5, 1],
            [0.5, -0.91, 0.26, -0.5],
            [-0.26, -0.27, 0.17, 0.87]]  
biases = [2.0, 3.0, 0.5]

outputs = np.dot(inputs, np.array(weights).T) + biases
outputs
# Out:
# array([[ 4.8  ,  1.21 ,  2.385],
#        [ 8.9  , -1.81 ,  0.2  ],
#        [ 1.41 ,  1.051,  0.026]])

# %%
outputs = np.dot(inputs, np.array(weights).T)
outputs
# Out:
# array([[ 2.8  , -1.79 ,  1.885],
#        [ 6.9  , -4.81 , -0.3  ],
#        [-0.59 , -1.949, -0.474]])

# %%
import numpy as np

inputs = [[1.0,2.0, 3.0, 2.5],
          [2.0, 5.0, -1.0, 2.0],
          [-1.5, 2.7, 3.3, -0.8]]

weights = [[0.2, 0.8, -0.5, 1],
            [0.5, -0.91, 0.26, -0.5],
            [-0.26, -0.27, 0.17, 0.87]]

Layer_output = np.dot(inputs, np.array(weights).T) + biases

Layer_output
# Out:
# array([[ 4.8  ,  1.21 ,  2.385],
#        [ 8.9  , -1.81 ,  0.2  ],
#        [ 1.41 ,  1.051,  0.026]])

# %%
import numpy as np
import nnfs
from nnfs.datasets import spiral_data

nnfs.init()

n_inputs = 2
n_neurons = 4

weights = 0.01 * np.random.randn(n_inputs, n_neurons)
biases = np.zeros((1, n_neurons))
print(weights)
print(biases)
# Out:
# [[ 0.01764052  0.00400157  0.00978738  0.02240893]
#  [ 0.01867558 -0.00977278  0.00950088 -0.00151357]]
# [[0. 0. 0. 0.]]

# %% [markdown]
# # Dense Layer

# %%
# Dense layer
class Layer_Dense:
 
# Layer initialization
    def __init__(self, n_inputs, n_neurons):
        # Initialize weights and biases
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))

    # Forward pass
    def forward(self, inputs):
        # Calculate output values from inputs, weights and biases
        self.output = np.dot(inputs, self.weights) + self.biases

# %%
# Create dataset
X, y = spiral_data(samples=100, classes=3)
# Create Dense layer with 2 input features and 3 output values
dense1 = Layer_Dense(2, 3)
# Perform a forward pass of our training data through this layer
dense1.forward(X)
# Let's see output of the first few samples:
print(dense1.output[:5])
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.24927217e-04 -1.13383176e-04 -7.44427671e-05]
#  [ 2.47531279e-04 -2.27871249e-04 -1.49413201e-04]
#  [ 3.48339119e-04 -2.17201712e-04 -1.48695675e-04]
#  [ 5.06213692e-04 -3.67755594e-04 -2.47095915e-04]]

# %% [markdown]
# # Relu Activation Function

# %%
inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]

output = []
for i in inputs:
    if i > 0:
        output.append(i)
    else:
        output.append(0)
output
# Out:
# [0, 2, 0, 3.3, 0, 1.1, 2.2, 0]

# %%
inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]
output = []
for i in inputs:
    output.append(max(0, i))
output
# Out:
# [0, 2, 0, 3.3, 0, 1.1, 2.2, 0]

# %% [markdown]
# # With Numpy

# %%
import numpy as np
inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]
output = np.maximum(0, inputs)
output
# Out:
# array([0. , 2. , 0. , 3.3, 0. , 1.1, 2.2, 0. ])

# %% [markdown]
# # Relu Activation

# %%
class Activation_Relu:
    #Forward pass
    def forward(self, inputs):
        # Calculate output values from input
        self.output = np.maximum(0, inputs)

# %% [markdown]
# # Softmax Activation

# %%
class Activation_Softmax:
    # Forward pass
    def forward(self, inputs):
        # Get unnormalized probabilities
        exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))

        # Normalization them for each sample
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)

        self.output = probabilities

# %% [markdown]
# ![Screenshot (71).png](attachment:78d0d12d-1972-49a1-94c8-d8dd56188035.png)

# %% [markdown]
# # Normalization

# %%
u = [1, 2]
y = [1/(1+2), 2/(1+2)]
y
# Out:
# [0.3333333333333333, 0.6666666666666666]

# %% [markdown]
# ### We want to drop the negative sign without losing the meaning

# %%
u = [-4, 1]
y = [-4/(-4+1), 1/(-4+1)]
y
# Out:
# [1.3333333333333333, -0.3333333333333333]

# %%
layer_outputs = [4.8, 1.21, 2.385]

# For each value in a vector, Calculate the exponential value
exp_values = np.exp(layer_outputs)
print("exponentiated values: ")
print(exp_values)


# Now normalize values
norm_values = exp_values / np.sum(exp_values)
print("normalized exponentiated values: ")
print(norm_values)
print("sum of normalized values: ", np.sum(norm_values))
# Out:
# exponentiated values:
# [121.51041752   3.35348465  10.85906266]
# normalized exponentiated values:
# [0.89528266 0.02470831 0.08000903]
# sum of normalized values:  0.9999999999999999

# %% [markdown]
# # To sum up

# %%
# Input -> Exponentiate -> Normalize -> Output
# Dog  Cat   Human
# [  1  , 2,     3] -> [e1, e2, e3] -> [e1/(e1+e2+e3), e2/(e1+e2+e3), e3/(e1+e2+e3)]
# The compination of Exponentiate and Normalization = SoftMax

# %% [markdown]
# ![Screenshot (73).png](attachment:5646f558-39fe-4355-acc0-69096b43be57.png)

# %% [markdown]
# # Testing

# %%
# Create dataset
X, y = spiral_data(samples=100, classes=3)
# Create Dense layer with 2 input features and 3 output values
dense1 = Layer_Dense(2, 3)
# Create ReLU activation (to be used with Dense layer):
activation1 = Activation_Relu()
# Create second Dense layer with 3 input features (as we take output
# of previous layer here) and 3 output values (output values)
dense2 = Layer_Dense(3, 3)
# Create Softmax activation (to be used with Dense layer):
activation2 = Activation_Softmax()
# Make a forward pass of our training data through this layer
dense1.forward(X)
# Make a forward pass through activation function
# it takes the output of first dense layer here
activation1.forward(dense1.output)
# Make a forward pass through second Dense layer
# it takes outputs of activation function of first layer as inputs
dense2.forward(activation1.output)
# Make a forward pass through activation function
# it takes the output of second dense layer here
activation2.forward(dense2.output)

# Let's see output of the first few samples:
print(activation2.output[:5])
# Out:
# [[0.33333334 0.33333334 0.33333334]
#  [0.33333358 0.33333343 0.33333305]
#  [0.33333376 0.3333335  0.33333275]
#  [0.33333397 0.33333355 0.33333242]
#  [0.33333415 0.33333367 0.33333215]]

# %% [markdown]
# # Lose Function
# ## Categorical Cross-Entropy

# %% [markdown]
# ![Screenshot (75).png](attachment:666ec8e7-d8de-4bb7-8660-74ecfb3af59a.png)

# %% [markdown]
# # After OnehotEncoding

# %% [markdown]
# ![Screenshot (78).png](attachment:2fe93545-934b-43b6-b17e-8e4703894c5e.png)

# %% [markdown]
# # Explaining What is OneHotEncoding

# %%
# One-hot encoding : Vector its length equal to the number of classes we have in out case

Classes = 2
Label = 0
One-hot = [1, 0]
----------------------------------------------------
Classes = 2
Label = 1
One-hot = [0, 1]
----------------------------------------------------
Classes = 3
Label = 0
One-hot = [1, 0, 0]
----------------------------------------------------
Classes = 3
Label = 2
One-hot = [0, 0, 1]
-----------------------------------------------------
Classes = 4
Label = 3
One-hot = [0, 0, 0, 1]

# %% [markdown]
# # Categorical Cross-Entropy

# %%
import math
# An example output from the output layer of the neural network
softmax_output = [0.7, 0.1, 0.2]
# Ground truth
target_output = [1, 0, 0]

loss = -(math.log(softmax_output[0])*target_output[0] +
         math.log(softmax_output[1])*target_output[1] +
         math.log(softmax_output[2])*target_output[2])
loss
# Out:
# 0.35667494393873245

# %%
loss = -math.log(softmax_output[0])
loss
# Out:
# 0.35667494393873245

# %% [markdown]
# ![Screenshot (80).png](attachment:7ccbdaae-b33a-46b1-ac52-961ecad79a97.png)

# %%
print(-math.log(0.7))
print(-math.log(0.5))
# Out:
# 0.35667494393873245
# 0.6931471805599453

# %% [markdown]
# # Softmax with batch

# %%
softmax_outputs = [[0.7, 0.1, 0.2],
                   [0.1, 0.5, 0.4],
                   [0.02, 0.9, 0.08]]
class_targets = [0, 1, 1]
for targ_idx, distribution in zip(class_targets, softmax_outputs):
    print(distribution[targ_idx])
# Out:
# 0.7
# 0.5
# 0.9

# %% [markdown]
# # With Numpy

# %%
import numpy as np
softmax_outputs = np.array([[0.7, 0.1, 0.2],
                            [0.1, 0.5, 0.4],
                            [0.02, 0.9, 0.08]])
class_targets = [0, 1, 1]

print(softmax_outputs[[0, 1, 2], class_targets])
# Out:
# [0.7 0.5 0.9]

# %%
print(softmax_outputs[
range(len(softmax_outputs)), class_targets
])
# Out:
# [0.7 0.5 0.9]

# %%
print(-np.log(softmax_outputs[
range(len(softmax_outputs)), class_targets
]))
# Out:
# [0.35667494 0.69314718 0.10536052]
